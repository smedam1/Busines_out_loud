# %%
Home page -- https://businesoutloud-production-f617.up.railway.app/
news_waiting_page -- https://businesoutloud-production-f617.up.railway.app/news_waiting_page
news_page -- https://businesoutloud-production-f617.up.railway.app/news_page
magazine_page -- https://businesoutloud-production-f617.up.railway.app/magazine_page
magazine_page_read_onlye -- https://businesoutloud-production-f617.up.railway.app/magazine_page_read_only
category_homepagee -- https://businesoutloud-production-f617.up.railway.app/category_homepage
advertise_with_us -- https://businesoutloud-production-f617.up.railway.app/advertise_with_us
JD_page -- https://businesoutloud-production-f617.up.railway.app/JD
career_page -- https://businesoutloud-production-f617.up.railway.app/career_page

# %%
from static.data.db_handler import *
from static.data.global_functions import *

bucket_name = 'blog-images'
yy = get_file_details_db(bucket_name=bucket_name)
display(yy)

xx = delete_file_from_storage('.emptyFolderPlaceholder')
display(xx)

yy = get_file_details_db(bucket_name=bucket_name)
display(yy)
# Out:
# {'status': 'success',
#  'data': [{'name': 'ad_bg - Copy.png',
#    'size': '904.6 KB',
#    'id': 'fd37847d-aa56-4426-a173-7d2d6b5f3340',
#    'public_url': 'https://iwyjssxhrcucnrkzkvmt.supabase.co/storage/v1/object/public/blog-images/ad_bg - Copy.png'},
#   {'name': 'ad_bg.png',
#    'size': '904.6 KB',
#    'id': '6a626d72-4427-4126-986e-73a69d94c46c',
#    'public_url': 'https://iwyjssxhrcucnrkzkvmt.supabase.co/storage/v1/object/public/blog-images/ad_bg.png'},
#   {'name': '.emptyFolderPlaceholder',
#    'size': '0 B',
#    'id': '29948a0a-14ee-4ed9-ba2b-103efa0307ef',
#    'public_url': 'https://iwyjssxhrcucnrkzkvmt.supabase.co/storage/v1/object/public/blog-images/.emptyFolderPlaceholder'},
#   {'name': 'footer1.png',
#    'size': '4.1 MB',
#    'id': 'db04f388-24eb-4629-8fb2-7231bce91181',
#    'public_url': 'https://iwyjssxhrcucnrkzkvmt.supabase.co/storage/v1/object/public/blog-images/footer1.png'},
#   {'name': 'insta_logo.png',
#    'size': '11.2 KB',
#    'id': '292ed763-4f33-4ea4-a2a3-161592cf7ba9',
#    'public_url': 'https://iwyjssxhrcucnrkzkvmt.supabase.co/storage/v1/object/public/blog-images/insta_logo.png'},
#   {'name': 'real_business copy.png',
#    'size': '2.7 MB',
#    'id': '3c378374-79d1-4852-867c-4e90024464ad',
#    'public_url': 'https://iwyjssxhrcucnrkzkvmt.supabase.co/storage/v1/object/public/blog-images/real_business copy.png'},
#   {'name': 'real_business.png',
#    'size': '2.7 MB',
#    'id': '71b511e3-52b5-487f-b4e3-7142499452a5',
#    'public_url': 'https://iwyjssxhrcucnrkzkvmt.supabase.co/storage/v1/object/public/blog-images/real_business.png'}],
#  'public_url': 'https://iwyjssxhrcucnrkzkvmt.supabase.co/storage/v1/object/public/blog-images/ad_bg - Copy.png?'}
# {'status': 'success',
#  'message': "File '.emptyFolderPlaceholder' deleted successfully from blog-images"}
# {'status': 'success',
#  'data': [{'name': 'ad_bg - Copy.png',
#    'size': '904.6 KB',
#    'id': 'fd37847d-aa56-4426-a173-7d2d6b5f3340',
#    'public_url': 'https://iwyjssxhrcucnrkzkvmt.supabase.co/storage/v1/object/public/blog-images/ad_bg - Copy.png'},
#   {'name': 'ad_bg.png',
#    'size': '904.6 KB',
#    'id': '6a626d72-4427-4126-986e-73a69d94c46c',
#    'public_url': 'https://iwyjssxhrcucnrkzkvmt.supabase.co/storage/v1/object/public/blog-images/ad_bg.png'},
#   {'name': 'footer1.png',
#    'size': '4.1 MB',
#    'id': 'db04f388-24eb-4629-8fb2-7231bce91181',
#    'public_url': 'https://iwyjssxhrcucnrkzkvmt.supabase.co/storage/v1/object/public/blog-images/footer1.png'},
#   {'name': 'insta_logo.png',
#    'size': '11.2 KB',
#    'id': '292ed763-4f33-4ea4-a2a3-161592cf7ba9',
#    'public_url': 'https://iwyjssxhrcucnrkzkvmt.supabase.co/storage/v1/object/public/blog-images/insta_logo.png'},
#   {'name': 'real_business copy.png',
#    'size': '2.7 MB',
#    'id': '3c378374-79d1-4852-867c-4e90024464ad',
#    'public_url': 'https://iwyjssxhrcucnrkzkvmt.supabase.co/storage/v1/object/public/blog-images/real_business copy.png'},
#   {'name': 'real_business.png',
#    'size': '2.7 MB',
#    'id': '71b511e3-52b5-487f-b4e3-7142499452a5',
#    'public_url': 'https://iwyjssxhrcucnrkzkvmt.supabase.co/storage/v1/object/public/blog-images/real_business.png'}],
#  'public_url': 'https://iwyjssxhrcucnrkzkvmt.supabase.co/storage/v1/object/public/blog-images/ad_bg - Copy.png?'}

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get("http://127.0.0.1:5000/blog/innovative_approaches_to_talent_acquisition_&_retention_in_today's_professional_landscape")
soup = BeautifulSoup(res.text, 'html.parser')
soup

# %%
from static.data.db_handler import *
xx = get_recent_magazines_db()
# Out:
# Fetching recent magazines with limit: 9

# %%
xx
# Out:
# [{'id': '513ea3f5-9e2a-41eb-bd6b-87e2511c13e6',
#   'created_at': '2025-07-07T19:25:26.446182+00:00',
#   'pdf_url': 'https://iwyjssxhrcucnrkzkvmt.supabase.co/storage/v1/object/public/magazine-pdfs/7159.pdf.pdf?',
#   'thumbnail_url': 'https://picsum.photos/1920/1080/?random=abcm',
#   'title': 'test_3'},
#  {'id': 'c4642ff0-a18c-416f-b9bc-4237f1dc9c95',
#   'created_at': '2025-07-07T10:31:28.349433+00:00',
#   'pdf_url': 'https://iwyjssxhrcucnrkzkvmt.supabase.co/storage/v1/object/public/magazine-pdfs/test_magazine.pdf?',
#   'thumbnail_url': 'https://iwyjssxhrcucnrkzkvmt.supabase.co/storage/v1/object/public/magazine-thumbnails/1.sm.webp?',
#   'title': 'test_2'},
#  {'id': 'a72998f8-9546-4933-8688-0be16e82db98',
#   'created_at': '2025-06-27T20:42:02.035672+00:00',
#   'pdf_url': 'https://iwyjssxhrcucnrkzkvmt.supabase.co/storage/v1/object/public/magazine-pdfs//CXO%20TechBOT%20October%202024-1-10.pdf',
#   'thumbnail_url': 'https://picsum.photos/1920/1080/?random=abc',
#   'title': 'demo_title'}]

# %%
with open('temp.json', 'w') as f:
    
    json.dump(xx, f, indent=4)

# %%
import json
dd = json.loads(open('temp.json').read())
dd

# %%
for i in dd['data']:
    print(i[:100])
# Out:
# <header class="w-full bg-black relative">
#         <!-- Desktop Header -->
#         <div class="hidden
# <section class="w-full py-6 px-4 md:px-8">
#
#         <div class="flex flex-col md:flex-row ga
# <section class="w-full h-auto relative overflow-hidden my-5 md:my-0">
#         <div class="absolute
# <section
#             class="box-border w-full h-[90px] border-y border-black flex items-center overf
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 for i in dd['data']:
# ----> 2     print(i[:100])
#
# TypeError: 'NoneType' object is not subscriptable

# %%
from static.data.rss import get_trending_news
trending_news = await get_trending_news()

trending_news
# Out:
# {'title': '"I Was In The Room": S Jaishankar Refutes Trump\'s India-Pak Ceasefire Claims', 'description': 'Foreign Minister S Jaishankar on Monday called the terror attack in Jammu and Kashmir\'s Pehalgam an "act of economic warfare" meant to destroy tourism in Kashmir.', 'link': 'https://www.ndtv.com/world-news/eam-s-jaishankar-refutes-donald-trumps-india-pakistan-ceasefire-claims-i-was-in-the-room-8805736#publisher=newsstand', 'pub_date': '01 Jul 2025', 'media_url': 'https://c.ndtvimg.com/2025-07/snmfnl3k_modi-jaishankar-trump-split-afp-pti-_625x300_01_July_25.jpeg', 'platform': 'NDTV News'}
# {'title': 'Bryan Kohberger appears to accept plea deal', 'description': 'The suspect accused of killing four University of Idaho students appears to have reached a plea deal with prosecutors which will likely take the death penalty off the table. It comes just weeks ahead of his trial. NBC News’ Stephanie Gosk has the late details.', 'link': 'https://www.nbcnews.com/nightly-news/video/bryan-kohberger-appears-to-accept-plea-deal-242501189720', 'pub_date': '30 Jun 2025', 'media_url': 'https://media-cldnry.s-nbcnews.com/image/upload/t_fit_1500w/mpx/2704722219/2025_06/1751327676076_nn_sgo_kohberger_update_250630_1920x1080-j5zpi3.jpg', 'platform': 'NBC News'}
# {'title': 'California Rolls Back Its Landmark Environmental Law', 'description': 'Gov. Gavin Newsom and state lawmakers scaled back a law that was vilified for its role in California’s housing shortage and homelessness crisis.', 'link': 'https://www.nytimes.com/2025/06/30/us/california-environment-newsom-ceqa.html', 'pub_date': '01 Jul 2025', 'media_url': 'https://static01.nyt.com/images/2025/06/27/multimedia/00nat-ca-enviro-zcvw/00nat-ca-enviro-zcvw-mediumSquareAt3X.jpg', 'platform': 'New York Times'}
# '<article class="flex flex-col md:flex-row gap-4 md:w-full border-b border-white/30 pb-3.5"> \n                <div class="w-full md:w-[289.2px] h-[150px] bg-cover bg-center rounded-[6px] bg-[url(https://c.ndtvimg.com/2025-07/snmfnl3k_modi-jaishankar-trump-split-afp-pti-_625x300_01_July_25.jpeg)] flex-shrink-0"></div>\n                <div class="flex flex-col justify-center">\n                 <div class="w-auto md:w-[137.18px] h-[10px] font-jakarta font-medium text-[10px] leading-[1] text-white/60 mb-2">NDTV News - 01 Jul 2025</div>\n                 <a href="https://www.ndtv.com/world-news/eam-s-jaishankar-refutes-donald-trumps-india-pakistan-ceasefire-claims-i-was-in-the-room-8805736#publisher=newsstand" class="hover:underline">\n                     <h3 class="w-auto md:w-auto h-auto font-jakarta font-normal text-lg leading-[136.9%] text-white mb-2">"I Was In The Room": S Jaishankar Refutes Trump\'s India-Pak Ceasefire Claims</h3>\n                 </a>\n                 <p class="w-auto md:w-auto h-auto font-jakarta font-normal text-xs leading-[123.9%] text-white">Foreign Minister S Jaishankar on Monday called the terror attack in Jammu and Kashmir\'s Pehalgam an "act of ec...</p> \n                </div>\n            </article>\n<article class="flex flex-col md:flex-row gap-4 md:w-full border-b border-white/30 pb-3.5"> \n                <div class="w-full md:w-[289.2px] h-[150px] bg-cover bg-center rounded-[6px] bg-[url(https://media-cldnry.s-nbcnews.com/image/upload/t_fit_1500w/mpx/2704722219/2025_06/1751327676076_nn_sgo_kohberger_update_250630_1920x1080-j5zpi3.jpg)] flex-shrink-0"></div>\n                <div class="flex flex-col justify-center">\n                 <div class="w-auto md:w-[137.18px] h-[10px] font-jakarta font-medium text-[10px] leading-[1] text-white/60 mb-2">NBC News - 30 Jun 2025</div>\n                 <a href="https://www.nbcnews.com/nightly-news/video/bryan-kohberger-appears-to-accept-plea-deal-242501189720" class="hover:underline">\n                     <h3 class="w-auto md:w-auto h-auto font-jakarta font-normal text-lg leading-[136.9%] text-white mb-2">Bryan Kohberger appears to accept plea deal</h3>\n                 </a>\n                 <p class="w-auto md:w-auto h-auto font-jakarta font-normal text-xs leading-[123.9%] text-white">The suspect accused of killing four University of Idaho students appears to have reached a plea deal with pros...</p> \n                </div>\n            </article>\n<article class="flex flex-col md:flex-row gap-4 md:w-full border-b border-white/30 pb-3.5"> \n                <div class="w-full md:w-[289.2px] h-[150px] bg-cover bg-center rounded-[6px] bg-[url(https://static01.nyt.com/images/2025/06/27/multimedia/00nat-ca-enviro-zcvw/00nat-ca-enviro-zcvw-mediumSquareAt3X.jpg)] flex-shrink-0"></div>\n                <div class="flex flex-col justify-center">\n                 <div class="w-auto md:w-[137.18px] h-[10px] font-jakarta font-medium text-[10px] leading-[1] text-white/60 mb-2">New York Times - 01 Jul 2025</div>\n                 <a href="https://www.nytimes.com/2025/06/30/us/california-environment-newsom-ceqa.html" class="hover:underline">\n                     <h3 class="w-auto md:w-auto h-auto font-jakarta font-normal text-lg leading-[136.9%] text-white mb-2">California Rolls Back Its Landmark Environmental Law</h3>\n                 </a>\n                 <p class="w-auto md:w-auto h-auto font-jakarta font-normal text-xs leading-[123.9%] text-white">Gov. Gavin Newsom and state lawmakers scaled back a law that was vilified for its role in California’s housing...</p> \n                </div>\n            </article>\n'

# %%
from static.data.db_handler import get_blogs_by_category

blogs = get_blogs_by_category('technology'.upper())
blogs
# Out:
# [{'id': 'the_world_in_2025:_how_artificial_intelligence_will_redefine_our_reality',
#   'created_at': '2025-07-06T19:38:11.080455+00:00',
#   'updated_at': '2025-07-06T19:38:11.080455+00:00',
#   'created_by': 'admin',
#   'updated_by': None,
#   'json_data': {'blogDate': '2025-07-06',
#    'seoTitle': 'AI in 2025: The Next Frontier of Innovation & Disruption',
#    'blogTitle': 'The World in 2025: How Artificial Intelligence Will Redefine Our Reality',
#    'blogAuthor': 'Alex Chen',
#    'blogStatus': 'draft',
#    'blogSummary': 'As 2025 approaches, Artificial Intelligence is set to move beyond its current capabilities, becoming more integrated, intuitive, and indispensable. This article delves into the key predictions for AI, examining its role in revolutionizing industries, personalizing daily life, and tackling global challenges.',
#    'blogCategory': 'TECHNOLOGY',
#    'mainImageAlt': 'Futuristic illustration of a humanoid AI interacting with a complex digital interface, symbolizing the advancements of AI in 2025.',
#    'mainImageUrl': 'https://images.pexels.com/photos/8386440/pexels-photo-8386440.jpeg?auto=compress&cs=tinysrgb&w=1260&h=750&dpr=1',
#    'dynamicSections': [{'id': 'section_1',
#      'type': 'h1',
#      'content': 'Introduction: Beyond the Hype'},
#     {'id': 'section_2',
#      'type': 'text',
#      'content': "The conversation around Artificial Intelligence has long been a mix of science fiction and practical application. As we stand on the cusp of 2025, the theoretical is rapidly becoming the tangible. AI is evolving from a tool for specific tasks into a foundational layer of our digital and physical worlds. This isn't about sentient robots; it's about smarter systems, deeper insights, and a fundamental shift in how we work, live, and interact."},
#     {'id': 'section_3',
#      'type': 'h2',
#      'content': '1. Hyper-Personalization at Scale'},
#     {'id': 'section_4',
#      'type': 'text',
#      'content': "By 2025, the concept of personalization will be supercharged by AI. Expect predictive models that don't just know what you bought, but why you bought it, and what you'll need next. In retail, this means curated shopping experiences that feel uniquely yours. In entertainment, streaming services will generate dynamic content trailers and recommendations with uncanny accuracy. Your digital life will be less about searching and more about being presented with what you need, before you even realize it."},
#     {'id': 'section_5',
#      'type': 'image',
#      'content': {'alt': 'AI algorithm flowchart showing connections between data points, representing hyper-personalization.',
#       'url': 'https://images.pexels.com/photos/5952243/pexels-photo-5952243.jpeg?auto=compress&cs=tinysrgb&w=1260&h=750&dpr=1'}},
#     {'id': 'section_6',
#      'type': 'h2',
#      'content': '2. The Rise of Autonomous Systems'},
#     {'id': 'section_7',
#      'type': 'text',
#      'content': "While fully autonomous cars on every street might still be a few years away, the integration of Level 4 autonomous systems in controlled environments like logistics, shipping, and public transport will be commonplace. AI will manage entire supply chains, optimizing routes for delivery drones and autonomous trucks to reduce emissions and increase efficiency. In manufacturing, 'lights-out' factories run by AI-powered robotics will become more prevalent, operating 24/7 with minimal human intervention."},
#     {'id': 'section_8',
#      'type': 'h2',
#      'content': '3. A Revolution in Healthcare and Science'},
#     {'id': 'section_9',
#      'type': 'text',
#      'content': "AI's impact on healthcare will be profound. In 2025, AI-powered diagnostic tools will assist doctors in identifying diseases like cancer from medical scans with greater speed and accuracy than the human eye. Drug discovery, a traditionally slow and expensive process, will be accelerated as AI models simulate molecular interactions to find promising new compounds. We will also see a rise in personalized medicine, where treatment plans are tailored to an individual's genetic makeup and lifestyle, all powered by AI analysis."},
#     {'id': 'section_10',
#      'type': 'h2',
#      'content': '4. AI as a Creative and Collaborative Partner'},
#     {'id': 'section_11',
#      'type': 'text',
#      'content': 'Far from replacing human creativity, AI in 2025 will become an indispensable creative partner. Musicians will use AI to generate novel melodies, artists will collaborate with generative models to create stunning visual works, and writers will use advanced language models for research, brainstorming, and editing. The focus will shift from the act of creation to the art of curation and direction, with humans guiding AI tools to achieve their creative vision.'},
#     {'id': 'section_12',
#      'type': 'h1',
#      'content': 'Conclusion: Navigating the New Normal'},
#     {'id': 'section_13',
#      'type': 'text',
#      'content': "The world in 2025 will be inextricably linked with Artificial Intelligence. Its integration will bring unprecedented efficiency, personalization, and discovery. However, this rapid advancement also necessitates a global conversation on ethics, governance, and job displacement. Successfully navigating this new era requires not just technological prowess, but a commitment to building a future where AI serves humanity as a whole. The next frontier is here, and it's powered by intelligence—both artificial and human."}],
#    'seoCanonicalUrl': 'https://brandsoutloud.com/blog/ai-in-2025',
#    'adBannerBelowUrl': 'https://picsum.photos/1920/1080/?random=129',
#    'adBannerBelowHref': 'ad',
#    'adBannerBesideUrl': 'https://picsum.photos/1920/1080/?random=125',
#    'adBannerBesideHref': 'ad',
#    'labelsNotMandatory': False,
#    'seoMetaDescription': 'Explore the transformative impact of AI in 2025. From hyper-personalization and autonomous systems to advancements in healthcare and creative industries, discover the key trends shaping our future.'},
#   'history': [{'date': '2025-07-06', 'admin_name': 'admin'},
#    {'date': '2025-07-06', 'action': 'updated', 'admin_name': 'admin'}],
#   'status': 'draft',
#   'category': 'TECHNOLOGY',
#   'sub_category': None,
#   'meta_tags': '<title>AI in 2025: The Next Frontier of Innovation & Disruption</title>\n    <meta name="description" content="Explore the transformative impact of AI in 2025. From hyper-personalization and autonomous systems to advancements in healthcare and creative industries, discover the key trends shaping our future.">\n    <meta property="og:title" content="AI in 2025: The Next Frontier of Innovation & Disruption">\n    <meta property="og:description" content="Explore the transformative impact of AI in 2025. From hyper-personalization and autonomous systems to advancements in healthcare and creative industries, discover the key trends shaping our future.">\n    <meta property="og:image" content="https://images.pexels.com/photos/8386440/pexels-photo-8386440.jpeg?auto=compress&cs=tinysrgb&w=1260&h=750&dpr=1">\n    <meta property="og:url" content="https://brandsoutloud.com/blog/ai-in-2025">\n    <meta property="og:type" content="article">\n    <meta name="twitter:card" content="summary_large_image">\n    <meta name="twitter:title" content="AI in 2025: The Next Frontier of Innovation & Disruption">\n    <meta name="twitter:description" content="Explore the transformative impact of AI in 2025. From hyper-personalization and autonomous systems to advancements in healthcare and creative industries, discover the key trends shaping our future.">\n    <meta name="twitter:image" content="https://images.pexels.com/photos/8386440/pexels-photo-8386440.jpeg?auto=compress&cs=tinysrgb&w=1260&h=750&dpr=1">\n    <link rel="canonical" href="https://brandsoutloud.com/blog/ai-in-2025">',
#   'redirect_url': None,
#   'labels': {'AI in 2025': 75000,
#    'Future of AI': 110000,
#    'AI Technology': 95000,
#    'AI in Healthcare': 65000,
#    'Machine Learning 2025': 32000,
#    'Artificial Intelligence Trends': 45000}},
#  {'id': 'from_hype_to_reality:_the_practical_applications_of_spatial_computing',
#   'created_at': '2025-06-29T06:52:51.328848+00:00',
#   'updated_at': '2025-06-29T06:52:51.328848+00:00',
#   'created_by': 'admin',
#   'updated_by': None,
#   'json_data': {'blogDate': '2025-06-29',
#    'seoTitle': '',
#    'blogTitle': 'From Hype to Reality: The Practical Applications of Spatial Computing',
#    'blogAuthor': 'Ben Carter',
#    'blogSummary': 'Beyond the buzzword of "the metaverse," spatial computing is quietly revolutionizing industries by blending the digital and physical worlds. This article explores the real-world applications of this technology in training, design, and collaboration that are already delivering tangible value.',
#    'blogCategory': 'Technology',
#    'mainImageAlt': 'main alt',
#    'mainImageUrl': 'https://iwyjssxhrcucnrkzkvmt.supabase.co/storage/v1/object/public/blog-images/minimalist-mountains-19.jpg',
#    'dynamicSections': [{'id': 'section_1',
#      'type': 'h1',
#      'content': 'What is Spatial Computing, Really?'},
#     {'id': 'section_2',
#      'type': 'text',
#      'content': 'Spatial computing is the digitization of the space around us, allowing machines to understand and interact with the real world. Think of it as the next evolution beyond the flat screens of desktops and smartphones. Using technologies like Augmented Reality (AR) and Virtual Reality (VR), it enables us to place and manipulate digital objects in our physical environment as if they were really there.'},
#     {'id': 'section_3',
#      'type': 'h2',
#      'content': 'Revolutionizing Training and Collaboration'},
#     {'id': 'section_4',
#      'type': 'text',
#      'content': "The most immediate impact of spatial computing is in professional settings. Surgeons can practice complex procedures on a virtual patient, reducing risks. Engineers and architects can walk through a full-scale digital model of a building before a single brick is laid. Remote teams can gather in a virtual meeting room to collaborate on a 3D model, feeling a sense of presence that video calls can't replicate. These are not future fantasies; they are happening today."}],
#    'seoCanonicalUrl': '',
#    'adBannerBelowUrl': '',
#    'adBannerBelowHref': '',
#    'adBannerBesideUrl': '',
#    'adBannerBesideHref': '',
#    'seoMetaDescription': ''},
#   'history': [{'date': '2025-06-29', 'admin_name': 'admin'}],
#   'status': 'draft',
#   'category': 'TECHNOLOGY',
#   'sub_category': None,
#   'meta_tags': '<title>From Hype to Reality: The Practical Applications of Spatial Computing</title>\n    <meta name="description" content="Beyond the buzzword of "the metaverse," spatial computing is quietly revolutionizing industries by blending the digital and physical worlds. This article explores the real-world applications of this technology in training, design, and collaboration that are already delivering tangible value.">\n    <meta property="og:title" content="From Hype to Reality: The Practical Applications of Spatial Computing">\n    <meta property="og:description" content="Beyond the buzzword of "the metaverse," spatial computing is quietly revolutionizing industries by blending the digital and physical worlds. This article explores the real-world applications of this technology in training, design, and collaboration that are already delivering tangible value.">\n    <meta property="og:image" content="https://iwyjssxhrcucnrkzkvmt.supabase.co/storage/v1/object/public/blog-images/minimalist-mountains-19.jpg">\n    <meta property="og:url" content="http://127.0.0.1:5000/blog/from_hype_to_reality:_the_practical_applications_of_spatial_computing">\n    <meta property="og:type" content="article">\n    <meta name="twitter:card" content="summary_large_image">\n    <meta name="twitter:title" content="From Hype to Reality: The Practical Applications of Spatial Computing">\n    <meta name="twitter:description" content="Beyond the buzzword of "the metaverse," spatial computing is quietly revolutionizing industries by blending the digital and physical worlds. This article explores the real-world applications of this technology in training, design, and collaboration that are already delivering tangible value.">\n    <meta name="twitter:image" content="https://iwyjssxhrcucnrkzkvmt.supabase.co/storage/v1/object/public/blog-images/minimalist-mountains-19.jpg">\n    <link rel="canonical" href="http://127.0.0.1:5000/blog/from_hype_to_reality:_the_practical_applications_of_spatial_computing">',
#   'redirect_url': None,
#   'labels': None},
#  {'id': 'zero_trust,_maximum_security:_a_new_paradigm_for_a_borderless_world',
#   'created_at': '2025-06-29T06:51:01.103045+00:00',
#   'updated_at': '2025-06-29T06:51:01.103045+00:00',
#   'created_by': 'admin',
#   'updated_by': None,
#   'json_data': {'blogDate': '2025-06-29',
#    'seoTitle': '',
#    'blogTitle': 'Zero Trust, Maximum Security: A New Paradigm for a Borderless World',
#    'blogAuthor': 'Alex Vasquez',
#    'blogSummary': 'The old "castle-and-moat" security model is obsolete in an age of cloud computing and remote work. This post explains the "Zero Trust" security framework, a modern approach built on the principle of "never trust, always verify," and why it\'s essential for protecting data in today\'s perimeter-less networks.',
#    'blogCategory': 'Technology',
#    'mainImageAlt': 'main alt',
#    'mainImageUrl': 'https://iwyjssxhrcucnrkzkvmt.supabase.co/storage/v1/object/public/blog-images/minimalist-mountains-19.jpg',
#    'dynamicSections': [{'id': 'section_1',
#      'type': 'h1',
#      'content': 'The Flaw in the Castle-and-Moat Model'},
#     {'id': 'section_2',
#      'type': 'text',
#      'content': 'Traditional security focused on building a strong perimeter (the moat) to protect the internal network (the castle). Once a hacker breached that perimeter, they often had free rein inside. With employees accessing cloud apps from anywhere, the "perimeter" no longer exists. The Zero Trust model assumes that threats can exist both inside and outside the network, so it eliminates the idea of a trusted internal zone.'},
#     {'id': 'section_3',
#      'type': 'h2',
#      'content': 'The Core Principles of Zero Trust'},
#     {'id': 'section_4',
#      'type': 'text',
#      'content': 'Zero Trust operates on three core principles: 1) Verify Explicitly: Always authenticate and authorize based on all available data points, including user identity, location, device health, and more. 2) Use Least Privilege Access: Grant users access only to the resources they absolutely need to do their jobs, and no more. 3) Assume Breach: Minimize the potential blast radius of an attack by segmenting networks and continuously monitoring for threats. This shifts security from a static defense to a dynamic, ongoing process.'}],
#    'seoCanonicalUrl': '',
#    'adBannerBelowUrl': '',
#    'adBannerBelowHref': '',
#    'adBannerBesideUrl': '',
#    'adBannerBesideHref': '',
#    'seoMetaDescription': ''},
#   'history': [{'date': '2025-06-29', 'admin_name': 'admin'}],
#   'status': 'draft',
#   'category': 'TECHNOLOGY',
#   'sub_category': None,
#   'meta_tags': '<title>Zero Trust, Maximum Security: A New Paradigm for a Borderless World</title>\n    <meta name="description" content="The old "castle-and-moat" security model is obsolete in an age of cloud computing and remote work. This post explains the "Zero Trust" security framework, a modern approach built on the principle of "never trust, always verify," and why it\'s essential for protecting data in today\'s perimeter-less networks.">\n    <meta property="og:title" content="Zero Trust, Maximum Security: A New Paradigm for a Borderless World">\n    <meta property="og:description" content="The old "castle-and-moat" security model is obsolete in an age of cloud computing and remote work. This post explains the "Zero Trust" security framework, a modern approach built on the principle of "never trust, always verify," and why it\'s essential for protecting data in today\'s perimeter-less networks.">\n    <meta property="og:image" content="https://iwyjssxhrcucnrkzkvmt.supabase.co/storage/v1/object/public/blog-images/minimalist-mountains-19.jpg">\n    <meta property="og:url" content="http://127.0.0.1:5000/blog/zero_trust,_maximum_security:_a_new_paradigm_for_a_borderless_world">\n    <meta property="og:type" content="article">\n    <meta name="twitter:card" content="summary_large_image">\n    <meta name="twitter:title" content="Zero Trust, Maximum Security: A New Paradigm for a Borderless World">\n    <meta name="twitter:description" content="The old "castle-and-moat" security model is obsolete in an age of cloud computing and remote work. This post explains the "Zero Trust" security framework, a modern approach built on the principle of "never trust, always verify," and why it\'s essential for protecting data in today\'s perimeter-less networks.">\n    <meta name="twitter:image" content="https://iwyjssxhrcucnrkzkvmt.supabase.co/storage/v1/object/public/blog-images/minimalist-mountains-19.jpg">\n    <link rel="canonical" href="http://127.0.0.1:5000/blog/zero_trust,_maximum_security:_a_new_paradigm_for_a_borderless_world">',
#   'redirect_url': None,
#   'labels': None},
#  {'id': 'quantum_leap:_how_quantum_computing_will_redefine_our_world',
#   'created_at': '2025-06-29T06:49:26.153643+00:00',
#   'updated_at': '2025-06-29T06:49:26.153643+00:00',
#   'created_by': 'admin',
#   'updated_by': None,
#   'json_data': {'blogDate': '2025-06-29',
#    'seoTitle': '',
#    'blogTitle': 'Quantum Leap: How Quantum Computing Will Redefine Our World',
#    'blogAuthor': 'Dr. Evelyn Reed',
#    'blogSummary': 'Moving beyond the ones and zeroes of classical computing, quantum computing promises to solve problems currently considered impossible. This blog explains the basics of quantum mechanics in simple terms and explores the industries—from medicine to finance—that are on the verge of a quantum-powered transformation.',
#    'blogCategory': 'Technology',
#    'mainImageAlt': 'main alt',
#    'mainImageUrl': 'https://iwyjssxhrcucnrkzkvmt.supabase.co/storage/v1/object/public/blog-images/minimalist-mountains-19.jpg',
#    'dynamicSections': [{'id': 'section_1',
#      'type': 'h1',
#      'content': 'Beyond Bits and Bytes: What is a Qubit?'},
#     {'id': 'section_2',
#      'type': 'text',
#      'content': 'A classical computer bit is either a 0 or a 1. A quantum bit, or "qubit," can be a 0, a 1, or both at the same time (a state called superposition). This, combined with another quantum phenomenon called entanglement, allows quantum computers to process a massive number of possibilities simultaneously. This exponential power is what sets them apart and will enable breakthroughs in complex problem-solving.'},
#     {'id': 'section_3',
#      'type': 'h2',
#      'content': 'Industries on the Brink of Transformation'},
#     {'id': 'section_4',
#      'type': 'text',
#      'content': 'The impact will be profound. In medicine, quantum computers could simulate molecules to design new drugs and therapies in a fraction of the time. In finance, they could create unbreakable encryption and run complex financial models to predict market behavior. They will also revolutionize materials science, leading to the development of more efficient batteries and superconductors. While widespread use is still years away, the foundational work is happening now.'}],
#    'seoCanonicalUrl': '',
#    'adBannerBelowUrl': '',
#    'adBannerBelowHref': '',
#    'adBannerBesideUrl': '',
#    'adBannerBesideHref': '',
#    'seoMetaDescription': ''},
#   'history': [{'date': '2025-06-29', 'admin_name': 'admin'}],
#   'status': 'draft',
#   'category': 'TECHNOLOGY',
#   'sub_category': None,
#   'meta_tags': '<title>Quantum Leap: How Quantum Computing Will Redefine Our World</title>\n    <meta name="description" content="Moving beyond the ones and zeroes of classical computing, quantum computing promises to solve problems currently considered impossible. This blog explains the basics of quantum mechanics in simple terms and explores the industries—from medicine to finance—that are on the verge of a quantum-powered transformation.">\n    <meta property="og:title" content="Quantum Leap: How Quantum Computing Will Redefine Our World">\n    <meta property="og:description" content="Moving beyond the ones and zeroes of classical computing, quantum computing promises to solve problems currently considered impossible. This blog explains the basics of quantum mechanics in simple terms and explores the industries—from medicine to finance—that are on the verge of a quantum-powered transformation.">\n    <meta property="og:image" content="https://iwyjssxhrcucnrkzkvmt.supabase.co/storage/v1/object/public/blog-images/minimalist-mountains-19.jpg">\n    <meta property="og:url" content="http://127.0.0.1:5000/blog/quantum_leap:_how_quantum_computing_will_redefine_our_world">\n    <meta property="og:type" content="article">\n    <meta name="twitter:card" content="summary_large_image">\n    <meta name="twitter:title" content="Quantum Leap: How Quantum Computing Will Redefine Our World">\n    <meta name="twitter:description" content="Moving beyond the ones and zeroes of classical computing, quantum computing promises to solve problems currently considered impossible. This blog explains the basics of quantum mechanics in simple terms and explores the industries—from medicine to finance—that are on the verge of a quantum-powered transformation.">\n    <meta name="twitter:image" content="https://iwyjssxhrcucnrkzkvmt.supabase.co/storage/v1/object/public/blog-images/minimalist-mountains-19.jpg">\n    <link rel="canonical" href="http://127.0.0.1:5000/blog/quantum_leap:_how_quantum_computing_will_redefine_our_world">',
#   'redirect_url': None,
#   'labels': None}]

# %%
blogs[0].get("category")
# Out:
# 'TECHNOLOGY'

# %%
from static.data.db_handler import get_blog
html = get_blog('the_world_in_2025:_how_artificial_intelligence_will_redefine_our_reality')
xx = html['json_data']

# %%
from static.data.page_handlers.blog_page import get_blog_body
get_blog_body(xx)

# %%
for i in final_product:
    print(i)
# Out:
# <div class="mb-3 toc-section" data-section-id="section_1">
#                     <a href="#section_1"
#                         data-toggle-target="#section_1"
#                         class="toc-h2-link flex items-center justify-between mt-1 mb-3 no-underline text-gray-800 hover:text-[#3533CD] transition-colors duration-200 toc-link">
#                         <div class="text-base font-medium">Introduction: Beyond the Hype</div>
#                         <i class="ph ph-caret-down text-xs ml-1 toc-arrow transition-transform duration-300"></i>
#                     </a>
#                     <div id="section_1" class="toc-subcategories hidden pl-4 mb-3 space-y-2">
#                         <a href="#section_3"
#                             class="flex items-center mt-1 no-underline text-gray-600 hover:text-[#3533CD] transition-colors duration-200 toc-link border-l-2 border-gray-200 pl-3 hover:border-[#3533CD]">
#                             <div class="text-sm">1. Hyper-Personalization at Scale</div>
#                         </a>
# <a href="#section_6"
#                             class="flex items-center mt-1 no-underline text-gray-600 hover:text-[#3533CD] transition-colors duration-200 toc-link border-l-2 border-gray-200 pl-3 hover:border-[#3533CD]">
#                             <div class="text-sm">2. The Rise of Autonomous Systems</div>
#                         </a>
# <a href="#section_8"
#                             class="flex items-center mt-1 no-underline text-gray-600 hover:text-[#3533CD] transition-colors duration-200 toc-link border-l-2 border-gray-200 pl-3 hover:border-[#3533CD]">
#                             <div class="text-sm">3. A Revolution in Healthcare and Science</div>
#                         </a>
# <a href="#section_10"
#                             class="flex items-center mt-1 no-underline text-gray-600 hover:text-[#3533CD] transition-colors duration-200 toc-link border-l-2 border-gray-200 pl-3 hover:border-[#3533CD]">
#                             <div class="text-sm">4. AI as a Creative and Collaborative Partner</div>
#                         </a>
#
#                     </div>
#                 </div>

# %%
# Example usage:
data = [
    {'id': 'section_1', 'type': 'h1', 'content': 'Introduction: Beyond the Hype'},
    {'id': 'section_3', 'type': 'h2', 'content': '1. Hyper-Personalization at Scale'},
    {'id': 'section_6', 'type': 'h2', 'content': '2. The Rise of Autonomous Systems'},
    {'id': 'section_8', 'type': 'h2', 'content': '3. A Revolution in Healthcare and Science'},
    {'id': 'section_10', 'type': 'h2', 'content': '4. AI as a Creative and Collaborative Partner'},
    {'id': 'section_12', 'type': 'h1', 'content': 'Conclusion: Navigating the New Normal'}
]

# Generate mobile TOC
mobile_toc = generate_mobile_toc(data)
print("Mobile TOC:")
print(mobile_toc)

print("\n" + "="*50 + "\n")

# Generate desktop TOC
desktop_toc = generate_desktop_toc(data)
print("Desktop TOC:")
print(desktop_toc)
# Out:
# Mobile TOC:
# <div class="block lg:hidden px-4 mt-8">
#             <div class="relative toc-container p-5 bg-white rounded-xl border-gray-100">
#                 <h2 class="text-xl font-bold text-[#3533CD] mb-4 border-b pb-3">Table of Contents</h2>
#                 <div class="mb-3 toc-section" data-section-id="section_1">
#                         <a href="#section_1"
#                             data-toggle-target="#sub-section_1"
#                             class="toc-h2-link flex items-center justify-between mt-1 mb-3 no-underline text-gray-800 hover:text-[#3533CD] transition-colors duration-200 toc-link">
#                             <div class="text-base font-medium">Introduction: Beyond the Hype</div>
#                             <i class="ph ph-caret-down text-xs ml-1 toc-arrow transition-transform duration-300"></i>
#                         </a>
#                         <div id="sub-section_1"
#                             class="toc-subcategories hidden pl-4 mb-3 space-y-2">
#                                                         <a href="#section_3"
#                                 class="flex items-center mt-1 no-underline text-gray-600 hover:text-[#3533CD] transition-colors duration-200 toc-link border-l-2 border-gray-200 pl-3 hover:border-[#3533CD]">
#                                 <div class="text-sm">1. Hyper-Personalization at Scale</div>
#                             </a>
#                             <a href="#section_6"
#                                 class="flex items-center mt-1 no-underline text-gray-600 hover:text-[#3533CD] transition-colors duration-200 toc-link border-l-2 border-gray-200 pl-3 hover:border-[#3533CD]">
#                                 <div class="text-sm">2. The Rise of Autonomous Systems</div>
#                             </a>
#                             <a href="#section_8"
#                                 class="flex items-center mt-1 no-underline text-gray-600 hover:text-[#3533CD] transition-colors duration-200 toc-link border-l-2 border-gray-200 pl-3 hover:border-[#3533CD]">
#                                 <div class="text-sm">3. A Revolution in Healthcare and Science</div>
#                             </a>
#                             <a href="#section_10"
#                                 class="flex items-center mt-1 no-underline text-gray-600 hover:text-[#3533CD] transition-colors duration-200 toc-link border-l-2 border-gray-200 pl-3 hover:border-[#3533CD]">
#                                 <div class="text-sm">4. AI as a Creative and Collaborative Partner</div>
#                             </a>
#                         </div>
#                     </div>
# <div class="mb-3 toc-section" data-section-id="section_12">
#                         <a href="#section_12"
#                             data-toggle-target="#sub-section_12"
#                             class="toc-h2-link flex items-center justify-between mt-1 mb-3 no-underline text-gray-800 hover:text-[#3533CD] transition-colors duration-200 toc-link">
#                             <div class="text-base font-medium">Conclusion: Navigating the New Normal</div>
#                             <i class="ph ph-caret-down text-xs ml-1 toc-arrow transition-transform duration-300"></i>
#                         </a>
#                         <div id="sub-section_12"
#                             class="toc-subcategories hidden pl-4 mb-3 space-y-2">
#
#                         </div>
#                     </div>
#                 <div class="mt-6 space-y-4 border-t pt-5">
#                     <button
#                         class="w-full h-[45px] bg-[#3533CD] rounded-xl flex items-center justify-center text-white font-jakarta font-medium text-[16px] leading-[120%] hover:bg-opacity-90 transition-colors shadow-md">
#                         <i class="ph ph-download mr-2"></i>Download Article as PDF
#                     </button>
#                     <div class="flex items-center flex-wrap">
#                         <div
#                             class="relative inline-flex items-center justify-center gap-2 bg-[#3533CD] rounded-xl h-[45px] px-4 cursor-pointer hover:bg-opacity-90 transition-colors shadow-md">
#                             <span class="text-white font-jakarta font-medium text-[16px] leading-[120%] text-center"
#                                 style="width: 7rem">
#                                 <i class="ph ph-share-network mr-2"></i>Share
#                             </span>
#                         </div>
#                         <div class="flex space-x-3 ml-3">
#                             <img src="static/images/whatsapp_logo.png" alt="WhatsApp"
#                                 class="w-[35px] h-[35px] object-contain hover:opacity-80 transition-opacity" />
#                             <img src="static/images/insta_logo.png" alt="Instagram"
#                                 class="w-[35px] h-[35px] object-contain hover:opacity-80 transition-opacity" />
#                         </div>
#                     </div>
#                 </div>
#             </div>
#         </div>
#
# ==================================================
#
# Desktop TOC:
# <aside class="sticky top-8 h-8rem lg:order-1 self-start md:mt-[0rem] mt-[-57rem]">
#                 <div class="p-6 flex flex-col w-full rounded-xl bg-white border-gray-100 hidden lg:block overflow-y- max-h-[calc(100vh-4rem)]"
#                     style="scroll-behavior: smooth">
#                     <h2 class="text-2xl font-bold text-[#3533CD] mb-6 border-b pb-3">Table of Contents</h2>
#                     <div class="mb-3 toc-section" data-section-id="section_1">
#                         <a href="#section_1"
#                             data-toggle-target="#sub-section_1"
#                             class="toc-h2-link flex items-center justify-between mt-1 mb-3 no-underline text-gray-800 hover:text-[#3533CD] transition-colors duration-200 toc-link">
#                             <div class="text-base font-medium">Introduction: Beyond the Hype</div>
#                             <i class="ph ph-caret-down text-xs ml-1 toc-arrow transition-transform duration-300"></i>
#                         </a>
#                         <div id="sub-section_1"
#                             class="toc-subcategories hidden pl-4 mb-3 space-y-2">
#                                                         <a href="#section_3"
#                                 class="flex items-center mt-1 no-underline text-gray-600 hover:text-[#3533CD] transition-colors duration-200 toc-link border-l-2 border-gray-200 pl-3 hover:border-[#3533CD]">
#                                 <div class="text-sm">1. Hyper-Personalization at Scale</div>
#                             </a>
#                             <a href="#section_6"
#                                 class="flex items-center mt-1 no-underline text-gray-600 hover:text-[#3533CD] transition-colors duration-200 toc-link border-l-2 border-gray-200 pl-3 hover:border-[#3533CD]">
#                                 <div class="text-sm">2. The Rise of Autonomous Systems</div>
#                             </a>
#                             <a href="#section_8"
#                                 class="flex items-center mt-1 no-underline text-gray-600 hover:text-[#3533CD] transition-colors duration-200 toc-link border-l-2 border-gray-200 pl-3 hover:border-[#3533CD]">
#                                 <div class="text-sm">3. A Revolution in Healthcare and Science</div>
#                             </a>
#                             <a href="#section_10"
#                                 class="flex items-center mt-1 no-underline text-gray-600 hover:text-[#3533CD] transition-colors duration-200 toc-link border-l-2 border-gray-200 pl-3 hover:border-[#3533CD]">
#                                 <div class="text-sm">4. AI as a Creative and Collaborative Partner</div>
#                             </a>
#                         </div>
#                     </div>
# <div class="mb-3 toc-section" data-section-id="section_12">
#                         <a href="#section_12"
#                             data-toggle-target="#sub-section_12"
#                             class="toc-h2-link flex items-center justify-between mt-1 mb-3 no-underline text-gray-800 hover:text-[#3533CD] transition-colors duration-200 toc-link">
#                             <div class="text-base font-medium">Conclusion: Navigating the New Normal</div>
#                             <i class="ph ph-caret-down text-xs ml-1 toc-arrow transition-transform duration-300"></i>
#                         </a>
#                         <div id="sub-section_12"
#                             class="toc-subcategories hidden pl-4 mb-3 space-y-2">
#
#                         </div>
#                     </div>
#                     <div class="mt-6 space-y-4 border-t pt-5">
#                         <button
#                             class="w-full h-[45px] bg-[#3533CD] rounded-xl flex items-center justify-center text-white font-jakarta font-medium text-[16px] leading-[120%] hover:bg-opacity-90 transition-colors shadow-md">
#                             <i class="ph ph-download mr-2"></i>Download Article as PDF
#                         </button>
#                         <div class="flex items-center flex-wrap">
#                             <div
#                                 class="relative inline-flex items-center justify-center gap-2 bg-[#3533CD] rounded-xl h-[45px] px-4 cursor-pointer hover:bg-opacity-90 transition-colors shadow-md">
#                                 <span class="text-white font-jakarta font-medium text-[16px] leading-[120%] text-center"
#                                     style="width: 7rem">
#                                     <i class="ph ph-share-network mr-2"></i>Share
#                                 </span>
#                             </div>
#                             <div class="flex space-x-3 ml-3">
#                                 <img src="static/images/whatsapp_logo.png" alt="WhatsApp"
#                                     class="w-[35px] h-[35px] object-contain hover:opacity-80 transition-opacity" />
#                                 <img src="static/images/insta_logo.png" alt="Instagram"
#                                     class="w-[35px] h-[35px] object-contain hover:opacity-80 transition-opacity" />
#                             </div>
#                         </div>
#                     </div>
#                 </div>
#             </aside>

# %%
from static.data.db_handler import get_recent_magazines_db
get_recent_magazines_db()
# Out:
# Fetching recent magazines with limit: 9
# [{'id': '513ea3f5-9e2a-41eb-bd6b-87e2511c13e6',
#   'created_at': '2025-07-07T19:25:26.446182+00:00',
#   'pdf_url': 'https://iwyjssxhrcucnrkzkvmt.supabase.co/storage/v1/object/public/magazine-pdfs/7159.pdf.pdf?',
#   'thumbnail_url': 'https://picsum.photos/1920/1080/?random=abcm',
#   'title': 'test_3'},
#  {'id': 'c4642ff0-a18c-416f-b9bc-4237f1dc9c95',
#   'created_at': '2025-07-07T10:31:28.349433+00:00',
#   'pdf_url': 'https://iwyjssxhrcucnrkzkvmt.supabase.co/storage/v1/object/public/magazine-pdfs/test_magazine.pdf?',
#   'thumbnail_url': 'https://iwyjssxhrcucnrkzkvmt.supabase.co/storage/v1/object/public/magazine-thumbnails/1.sm.webp?',
#   'title': 'test_2'},
#  {'id': 'a72998f8-9546-4933-8688-0be16e82db98',
#   'created_at': '2025-06-27T20:42:02.035672+00:00',
#   'pdf_url': 'https://iwyjssxhrcucnrkzkvmt.supabase.co/storage/v1/object/public/magazine-pdfs//CXO%20TechBOT%20October%202024-1-10.pdf',
#   'thumbnail_url': 'https://picsum.photos/1920/1080/?random=abc',
#   'title': 'demo_title'}]

# %%
import random

# Your data structure
data = [
    {"name": "apple", "percentage": 900},
    {"name": "banana", "percentage": 300},
    {"name": "orange", "percentage": 20},
    {"name": "grape", "percentage": 10}
]

# Extract names and weights
names = [item["name"] for item in data]
weights = [item["percentage"] for item in data]

# Choose one element based on weights
chosen = random.choices(names, weights=weights, k=1)[0]
print(f"Chosen: {chosen}")

# Choose multiple elements (e.g., 5 selections with replacement)
multiple_choices = random.choices(names, weights=weights, k=500)
print(multiple_choices.count('apple'), multiple_choices.count('banana'), multiple_choices.count('orange'), multiple_choices.count('grape'))
# Out:
# Chosen: apple
# 380 104 8 8

# %%
from supabase import create_client, Client
import hashlib
from dotenv import load_dotenv
import os
import random
load_dotenv()

from supabase import create_client, Client

url: str = os.environ.get("SUPABASE_URL")
key: str = os.environ.get("SUPABASE_KEY")
supabase: Client = create_client(url, key)

def get_chosen_orgs(k=1):
    """
    Choose one or more organizations based on their weights.
    
    :param data: List of dictionaries with 'name' and 'percentage'.
    :param k: Number of selections to make.
    :return: List of chosen organization names.
    """
    data = supabase.table("organization").select("organization,percentage").execute().data
    display(data)
    names = [item["organization"] for item in data]
    weights = [item["percentage"] for item in data]
    
    return random.choices(names, weights=weights, k=k)

get_chosen_orgs()
# Out:
# [{'organization': 'Amazon', 'percentage': 75},
#  {'organization': 'binkit', 'percentage': 25}]
# ['Amazon']

# %%
          <!-- Middle Flipbook Section -->
          <div class="col-span-1 lg:col-span-3">
            <div class="relative w-full max-w-[50rem] h-[33rem] mx-auto">
              {iframe}
            </div>
          </div>
          <!-- End of Middle Flipbook Section -->
